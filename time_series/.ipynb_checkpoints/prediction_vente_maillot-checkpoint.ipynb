# %%
import pandas
import matplotlib.pyplot as plt
import seaborn
# seaborn sert a rendre jolie les graphes

# %% [markdown]
# # import des données

# %%
file_path = r"C:\Users\anton\Desktop\Data\Hetic_cours_python\time_series\vente_maillots_de_bain.xlsx"
sales_df = pandas.read_excel(file_path, sheet_name = "Sheet2")

# %%
sales_df
# si je fait sales_df.head() ca donne les 5 premiere ligne
# si je fait sales_df.tail() ca donne les 5 derniere ligne
# Out:
#         Months  Sales
# 0   2001-01-01  139.7
# 1   2001-02-01  114.3
# 2   2001-03-01  101.6
# 3   2001-04-01  152.4
# 4   2001-05-01  215.9
# ..         ...    ...
# 103 2009-08-01  736.6
# 104 2009-09-01  685.5
# 105 2009-10-01  635.0
# 106 2009-11-01  622.3
# 107 2009-12-01  622.3
#
# [108 rows x 2 columns]

# %%
plt.figure(figsize=(15,6))
seaborn.scatterplot(x='Months', y='Sales', data=sales_df)
# la methode scatterplot nous permet d'afficher un nuage de point elle prend en paramettre x, y, et la source de donnée
plt.show()

# %%
index_x = [index for index in sales_df.index]
